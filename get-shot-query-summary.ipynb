# %% [markdown]
# This endpoint can be used to get shooting stats based on score and time parameters

# %%
import requests

# %% [markdown]
# ### 4th quarter and OT, game within 3 points with 2-5 minutes remaining

# %%
url = "https://api.pbpstats.com/get-shot-query-summary/nba"
params = {
    "Season": "2021-22",
    "SeasonType": "Regular Season",
    "Type": "Team", # Options: Team, Lineup, Opponent, LineupOpponent
    "FromMargin": -3,
    "ToMargin": 3,
    "FromTime": 300, # in seconds remaining in the period at the start of a possession
    "ToTime": 120, # in seconds remaining in the period at the start of a possession
    "PeriodGte": 4 # Could also use PeriodLte or period less than or equal to or PeriodEquals for period equal to
}
response = requests.get(url, params=params)
response_json = response.json()
response_json["results"]
# Out:
# [{'ab3_fg_pct': 0.458333333333333,
#   'ab3_fga': 24,
#   'ab3_fgm': 11,
#   'afg2m': 14,
#   'afg2pct': 0.56,
#   'afg3m': 10,
#   'afg3pct': 0.833333333333333,
#   'c3_fg_pct': 0.142857142857143,
#   'c3_fga': 7,
#   'c3_fgm': 1,
#   'efg': 0.477777777777778,
#   'fg2a': 59,
#   'fg2m': 25,
#   'fg2pct': 0.423728813559322,
#   'fg3a': 31,
#   'fg3m': 12,
#   'fg3pct': 0.387096774193548,
#   'fga': 90,
#   'lmr_fg_pct': 0.222222222222222,
#   'lmr_fga': 18,
#   'lmr_fgm': 4,
#   'name': 'LAC',
#   'putback_fg_pct': 0.333333333333333,
#   'putback_fga': 3,
#   'putback_fgm': 1,
#   'rim_fg_pct': 0.458333333333333,
#   'rim_fga': 24,
#   'rim_fgm': 11,
#   'smr_fg_pct': 0.588235294117647,
#   'smr_fga': 17,
#   'smr_fgm': 10,
#   'team_id': 1610612746},
#  {'ab3_fg_pct': 0.32258064516129,
#   'ab3_fga': 31,
#   'ab3_fgm': 10,
#   'afg2m': 17,
#   'afg2pct': 0.369565217391304,
#   'afg3m': 5,
#   'afg3pct': 0.416666666666667,
#   'c3_fg_pct': 0.2,
#   'c3_fga': 10,
#   'c3_fgm': 2,
#   'efg': 0.463768115942029,
#   'fg2a': 97,
#   'fg2m': 46,
#   'fg2pct': 0.474226804123711,
#   'fg3a': 41,
#   'fg3m': 12,
#   'fg3pct': 0.292682926829268,
#   'fga': 138,
#   'lmr_fg_pct': 0.227272727272727,
#   'lmr_fga': 22,
#   'lmr_fgm': 5,
#   'name': 'TOR',
#   'putback_fg_pct': 0.611111111111111,
#   'putback_fga': 18,
#   'putback_fgm': 11,
#   'rim_fg_pct': 0.652173913043478,
#   'rim_fga': 46,
#   'rim_fgm': 30,
#   'smr_fg_pct': 0.379310344827586,
#   'smr_fga': 29,
#   'smr_fgm': 11,
#   'team_id': 1610612761},
#  {'ab3_fg_pct': 0.290322580645161,
#   'ab3_fga': 31,
#   'ab3_fgm': 9,
#   'afg2m': 11,
#   'afg2pct': 0.34375,
#   'afg3m': 8,
#   'afg3pct': 0.727272727272727,
#   'c3_fg_pct': 0.25,
#   'c3_fga': 8,
#   'c3_fgm': 2,
#   'efg': 0.461904761904762,
#   'fg2a': 66,
#   'fg2m': 32,
#   'fg2pct': 0.484848484848485,
#   'fg3a': 39,
#   'fg3m': 11,
#   'fg3pct': 0.282051282051282,
#   'fga': 105,
#   'lmr_fg_pct': 0.5,
#   'lmr_fga': 6,
#   'lmr_fgm': 3,
#   'name': 'OKC',
#   'putback_fg_pct': 0.833333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 5,
#   'rim_fg_pct': 0.6,
#   'rim_fga': 40,
#   'rim_fgm': 24,
#   'smr_fg_pct': 0.25,
#   'smr_fga': 20,
#   'smr_fgm': 5,
#   'team_id': 1610612760},
#  {'ab3_fg_pct': 0.233333333333333,
#   'ab3_fga': 30,
#   'ab3_fgm': 7,
#   'afg2m': 17,
#   'afg2pct': 0.53125,
#   'afg3m': 6,
#   'afg3pct': 0.857142857142857,
#   'c3_fg_pct': 0.0,
#   'c3_fga': 6,
#   'c3_fgm': 0,
#   'efg': 0.400943396226415,
#   'fg2a': 70,
#   'fg2m': 32,
#   'fg2pct': 0.457142857142857,
#   'fg3a': 36,
#   'fg3m': 7,
#   'fg3pct': 0.194444444444444,
#   'fga': 106,
#   'lmr_fg_pct': 0.35,
#   'lmr_fga': 20,
#   'lmr_fgm': 7,
#   'name': 'SAS',
#   'putback_fg_pct': 0.333333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.56,
#   'rim_fga': 25,
#   'rim_fgm': 14,
#   'smr_fg_pct': 0.44,
#   'smr_fga': 25,
#   'smr_fgm': 11,
#   'team_id': 1610612759},
#  {'ab3_fg_pct': 0.28,
#   'ab3_fga': 25,
#   'ab3_fgm': 7,
#   'afg2m': 5,
#   'afg2pct': 0.208333333333333,
#   'afg3m': 4,
#   'afg3pct': 0.444444444444444,
#   'c3_fg_pct': 0.4,
#   'c3_fga': 5,
#   'c3_fgm': 2,
#   'efg': 0.487012987012987,
#   'fg2a': 47,
#   'fg2m': 24,
#   'fg2pct': 0.51063829787234,
#   'fg3a': 30,
#   'fg3m': 9,
#   'fg3pct': 0.3,
#   'fga': 77,
#   'lmr_fg_pct': 0.75,
#   'lmr_fga': 8,
#   'lmr_fgm': 6,
#   'name': 'MIN',
#   'putback_fg_pct': 0.75,
#   'putback_fga': 4,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.454545454545455,
#   'rim_fga': 22,
#   'rim_fgm': 10,
#   'smr_fg_pct': 0.470588235294118,
#   'smr_fga': 17,
#   'smr_fgm': 8,
#   'team_id': 1610612750},
#  {'ab3_fg_pct': 0.533333333333333,
#   'ab3_fga': 15,
#   'ab3_fgm': 8,
#   'afg2m': 28,
#   'afg2pct': 0.622222222222222,
#   'afg3m': 7,
#   'afg3pct': 0.777777777777778,
#   'c3_fg_pct': 0.142857142857143,
#   'c3_fga': 7,
#   'c3_fgm': 1,
#   'efg': 0.680232558139535,
#   'fg2a': 64,
#   'fg2m': 45,
#   'fg2pct': 0.703125,
#   'fg3a': 22,
#   'fg3m': 9,
#   'fg3pct': 0.409090909090909,
#   'fga': 86,
#   'lmr_fg_pct': 0.6,
#   'lmr_fga': 15,
#   'lmr_fgm': 9,
#   'name': 'PHX',
#   'putback_fg_pct': 1.0,
#   'putback_fga': 3,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.833333333333333,
#   'rim_fga': 24,
#   'rim_fgm': 20,
#   'smr_fg_pct': 0.64,
#   'smr_fga': 25,
#   'smr_fgm': 16,
#   'team_id': 1610612756},
#  {'ab3_fg_pct': 0.454545454545455,
#   'ab3_fga': 22,
#   'ab3_fgm': 10,
#   'afg2m': 11,
#   'afg2pct': 0.407407407407407,
#   'afg3m': 9,
#   'afg3pct': 0.818181818181818,
#   'c3_fg_pct': 0.2,
#   'c3_fga': 5,
#   'c3_fgm': 1,
#   'efg': 0.587837837837838,
#   'fg2a': 47,
#   'fg2m': 27,
#   'fg2pct': 0.574468085106383,
#   'fg3a': 27,
#   'fg3m': 11,
#   'fg3pct': 0.407407407407407,
#   'fga': 74,
#   'lmr_fg_pct': 0.666666666666667,
#   'lmr_fga': 3,
#   'lmr_fgm': 2,
#   'name': 'HOU',
#   'putback_fg_pct': 1.0,
#   'putback_fga': 3,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.703703703703704,
#   'rim_fga': 27,
#   'rim_fgm': 19,
#   'smr_fg_pct': 0.352941176470588,
#   'smr_fga': 17,
#   'smr_fgm': 6,
#   'team_id': 1610612745},
#  {'ab3_fg_pct': 0.4,
#   'ab3_fga': 20,
#   'ab3_fgm': 8,
#   'afg2m': 16,
#   'afg2pct': 0.4,
#   'afg3m': 14,
#   'afg3pct': 0.875,
#   'c3_fg_pct': 0.8,
#   'c3_fga': 10,
#   'c3_fgm': 8,
#   'efg': 0.615384615384615,
#   'fg2a': 74,
#   'fg2m': 40,
#   'fg2pct': 0.540540540540541,
#   'fg3a': 30,
#   'fg3m': 16,
#   'fg3pct': 0.533333333333333,
#   'fga': 104,
#   'lmr_fg_pct': 0.466666666666667,
#   'lmr_fga': 15,
#   'lmr_fgm': 7,
#   'name': 'WAS',
#   'putback_fg_pct': 0.5,
#   'putback_fga': 6,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.772727272727273,
#   'rim_fga': 22,
#   'rim_fgm': 17,
#   'smr_fg_pct': 0.432432432432432,
#   'smr_fga': 37,
#   'smr_fgm': 16,
#   'team_id': 1610612764},
#  {'ab3_fg_pct': 0.214285714285714,
#   'ab3_fga': 42,
#   'ab3_fgm': 9,
#   'afg2m': 13,
#   'afg2pct': 0.40625,
#   'afg3m': 5,
#   'afg3pct': 0.5,
#   'c3_fg_pct': 0.142857142857143,
#   'c3_fga': 7,
#   'c3_fgm': 1,
#   'efg': 0.3671875,
#   'fg2a': 79,
#   'fg2m': 32,
#   'fg2pct': 0.405063291139241,
#   'fg3a': 49,
#   'fg3m': 10,
#   'fg3pct': 0.204081632653061,
#   'fga': 128,
#   'lmr_fg_pct': 0.266666666666667,
#   'lmr_fga': 15,
#   'lmr_fgm': 4,
#   'name': 'IND',
#   'putback_fg_pct': 0.555555555555556,
#   'putback_fga': 9,
#   'putback_fgm': 5,
#   'rim_fg_pct': 0.486486486486487,
#   'rim_fga': 37,
#   'rim_fgm': 18,
#   'smr_fg_pct': 0.37037037037037,
#   'smr_fga': 27,
#   'smr_fgm': 10,
#   'team_id': 1610612754},
#  {'ab3_fg_pct': 0.08,
#   'ab3_fga': 25,
#   'ab3_fgm': 2,
#   'afg2m': 11,
#   'afg2pct': 0.379310344827586,
#   'afg3m': 2,
#   'afg3pct': 0.5,
#   'c3_fg_pct': 0.333333333333333,
#   'c3_fga': 6,
#   'c3_fgm': 2,
#   'efg': 0.411764705882353,
#   'fg2a': 54,
#   'fg2m': 29,
#   'fg2pct': 0.537037037037037,
#   'fg3a': 31,
#   'fg3m': 4,
#   'fg3pct': 0.129032258064516,
#   'fga': 85,
#   'lmr_fg_pct': 0.222222222222222,
#   'lmr_fga': 9,
#   'lmr_fgm': 2,
#   'name': 'ORL',
#   'putback_fg_pct': 0.5,
#   'putback_fga': 4,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.75,
#   'rim_fga': 20,
#   'rim_fgm': 15,
#   'smr_fg_pct': 0.48,
#   'smr_fga': 25,
#   'smr_fgm': 12,
#   'team_id': 1610612753},
#  {'ab3_fg_pct': 0.32,
#   'ab3_fga': 25,
#   'ab3_fgm': 8,
#   'afg2m': 8,
#   'afg2pct': 0.444444444444444,
#   'afg3m': 7,
#   'afg3pct': 0.7,
#   'c3_fg_pct': 0.4,
#   'c3_fga': 5,
#   'c3_fgm': 2,
#   'efg': 0.445945945945946,
#   'fg2a': 44,
#   'fg2m': 18,
#   'fg2pct': 0.409090909090909,
#   'fg3a': 30,
#   'fg3m': 10,
#   'fg3pct': 0.333333333333333,
#   'fga': 74,
#   'lmr_fg_pct': 0.75,
#   'lmr_fga': 4,
#   'lmr_fgm': 3,
#   'name': 'POR',
#   'putback_fg_pct': 0.5,
#   'putback_fga': 6,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.481481481481481,
#   'rim_fga': 27,
#   'rim_fgm': 13,
#   'smr_fg_pct': 0.153846153846154,
#   'smr_fga': 13,
#   'smr_fgm': 2,
#   'team_id': 1610612757},
#  {'ab3_fg_pct': 0.321428571428571,
#   'ab3_fga': 28,
#   'ab3_fgm': 9,
#   'afg2m': 21,
#   'afg2pct': 0.538461538461538,
#   'afg3m': 10,
#   'afg3pct': 0.769230769230769,
#   'c3_fg_pct': 0.333333333333333,
#   'c3_fga': 12,
#   'c3_fgm': 4,
#   'efg': 0.460629921259843,
#   'fg2a': 87,
#   'fg2m': 39,
#   'fg2pct': 0.448275862068966,
#   'fg3a': 40,
#   'fg3m': 13,
#   'fg3pct': 0.325,
#   'fga': 127,
#   'lmr_fg_pct': 0.409090909090909,
#   'lmr_fga': 22,
#   'lmr_fgm': 9,
#   'name': 'BKN',
#   'putback_fg_pct': 0.545454545454545,
#   'putback_fga': 11,
#   'putback_fgm': 6,
#   'rim_fg_pct': 0.575757575757576,
#   'rim_fga': 33,
#   'rim_fgm': 19,
#   'smr_fg_pct': 0.34375,
#   'smr_fga': 32,
#   'smr_fgm': 11,
#   'team_id': 1610612751},
#  {'ab3_fg_pct': 0.259259259259259,
#   'ab3_fga': 27,
#   'ab3_fgm': 7,
#   'afg2m': 6,
#   'afg2pct': 0.375,
#   'afg3m': 6,
#   'afg3pct': 0.545454545454545,
#   'c3_fg_pct': 0.666666666666667,
#   'c3_fga': 6,
#   'c3_fgm': 4,
#   'efg': 0.416666666666667,
#   'fg2a': 45,
#   'fg2m': 16,
#   'fg2pct': 0.355555555555556,
#   'fg3a': 33,
#   'fg3m': 11,
#   'fg3pct': 0.333333333333333,
#   'fga': 78,
#   'lmr_fg_pct': 0.25,
#   'lmr_fga': 12,
#   'lmr_fgm': 3,
#   'name': 'MIA',
#   'putback_fg_pct': 0.0,
#   'putback_fga': 1,
#   'putback_fgm': 0,
#   'rim_fg_pct': 0.470588235294118,
#   'rim_fga': 17,
#   'rim_fgm': 8,
#   'smr_fg_pct': 0.3125,
#   'smr_fga': 16,
#   'smr_fgm': 5,
#   'team_id': 1610612748},
#  {'ab3_fg_pct': 0.423076923076923,
#   'ab3_fga': 26,
#   'ab3_fgm': 11,
#   'afg2m': 8,
#   'afg2pct': 0.307692307692308,
#   'afg3m': 7,
#   'afg3pct': 0.538461538461538,
#   'c3_fg_pct': 0.25,
#   'c3_fga': 8,
#   'c3_fgm': 2,
#   'efg': 0.535294117647059,
#   'fg2a': 51,
#   'fg2m': 26,
#   'fg2pct': 0.509803921568627,
#   'fg3a': 34,
#   'fg3m': 13,
#   'fg3pct': 0.382352941176471,
#   'fga': 85,
#   'lmr_fg_pct': 0.666666666666667,
#   'lmr_fga': 6,
#   'lmr_fgm': 4,
#   'name': 'MIL',
#   'putback_fg_pct': 0.428571428571429,
#   'putback_fga': 7,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.541666666666667,
#   'rim_fga': 24,
#   'rim_fgm': 13,
#   'smr_fg_pct': 0.428571428571429,
#   'smr_fga': 21,
#   'smr_fgm': 9,
#   'team_id': 1610612749},
#  {'ab3_fg_pct': 0.173913043478261,
#   'ab3_fga': 23,
#   'ab3_fgm': 4,
#   'afg2m': 10,
#   'afg2pct': 0.3125,
#   'afg3m': 5,
#   'afg3pct': 0.714285714285714,
#   'c3_fg_pct': 0.25,
#   'c3_fga': 12,
#   'c3_fgm': 3,
#   'efg': 0.482954545454545,
#   'fg2a': 53,
#   'fg2m': 32,
#   'fg2pct': 0.60377358490566,
#   'fg3a': 35,
#   'fg3m': 7,
#   'fg3pct': 0.2,
#   'fga': 88,
#   'lmr_fg_pct': 0.272727272727273,
#   'lmr_fga': 11,
#   'lmr_fgm': 3,
#   'name': 'DAL',
#   'putback_fg_pct': 0.75,
#   'putback_fga': 4,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.733333333333333,
#   'rim_fga': 15,
#   'rim_fgm': 11,
#   'smr_fg_pct': 0.666666666666667,
#   'smr_fga': 27,
#   'smr_fgm': 18,
#   'team_id': 1610612742},
#  {'ab3_fg_pct': 0.225806451612903,
#   'ab3_fga': 31,
#   'ab3_fgm': 7,
#   'afg2m': 21,
#   'afg2pct': 0.5,
#   'afg3m': 11,
#   'afg3pct': 0.916666666666667,
#   'c3_fg_pct': 0.384615384615385,
#   'c3_fga': 13,
#   'c3_fgm': 5,
#   'efg': 0.465116279069767,
#   'fg2a': 85,
#   'fg2m': 42,
#   'fg2pct': 0.494117647058824,
#   'fg3a': 44,
#   'fg3m': 12,
#   'fg3pct': 0.272727272727273,
#   'fga': 129,
#   'lmr_fg_pct': 0.583333333333333,
#   'lmr_fga': 12,
#   'lmr_fgm': 7,
#   'name': 'DEN',
#   'putback_fg_pct': 0.692307692307692,
#   'putback_fga': 13,
#   'putback_fgm': 9,
#   'rim_fg_pct': 0.594594594594595,
#   'rim_fga': 37,
#   'rim_fgm': 22,
#   'smr_fg_pct': 0.361111111111111,
#   'smr_fga': 36,
#   'smr_fgm': 13,
#   'team_id': 1610612743},
#  {'ab3_fg_pct': 0.34375,
#   'ab3_fga': 32,
#   'ab3_fgm': 11,
#   'afg2m': 14,
#   'afg2pct': 0.388888888888889,
#   'afg3m': 12,
#   'afg3pct': 0.923076923076923,
#   'c3_fg_pct': 0.5,
#   'c3_fga': 4,
#   'c3_fgm': 2,
#   'efg': 0.533653846153846,
#   'fg2a': 68,
#   'fg2m': 36,
#   'fg2pct': 0.529411764705882,
#   'fg3a': 36,
#   'fg3m': 13,
#   'fg3pct': 0.361111111111111,
#   'fga': 104,
#   'lmr_fg_pct': 0.533333333333333,
#   'lmr_fga': 15,
#   'lmr_fgm': 8,
#   'name': 'SAC',
#   'putback_fg_pct': 0.333333333333333,
#   'putback_fga': 3,
#   'putback_fgm': 1,
#   'rim_fg_pct': 0.730769230769231,
#   'rim_fga': 26,
#   'rim_fgm': 19,
#   'smr_fg_pct': 0.333333333333333,
#   'smr_fga': 27,
#   'smr_fgm': 9,
#   'team_id': 1610612758},
#  {'ab3_fg_pct': 0.105263157894737,
#   'ab3_fga': 19,
#   'ab3_fgm': 2,
#   'afg2m': 8,
#   'afg2pct': 0.380952380952381,
#   'afg3m': 4,
#   'afg3pct': 1.0,
#   'c3_fg_pct': 0.333333333333333,
#   'c3_fga': 6,
#   'c3_fgm': 2,
#   'efg': 0.385714285714286,
#   'fg2a': 45,
#   'fg2m': 21,
#   'fg2pct': 0.466666666666667,
#   'fg3a': 25,
#   'fg3m': 4,
#   'fg3pct': 0.16,
#   'fga': 70,
#   'lmr_fg_pct': 0.4,
#   'lmr_fga': 5,
#   'lmr_fgm': 2,
#   'name': 'DET',
#   'putback_fg_pct': 0.833333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 5,
#   'rim_fg_pct': 0.65,
#   'rim_fga': 20,
#   'rim_fgm': 13,
#   'smr_fg_pct': 0.3,
#   'smr_fga': 20,
#   'smr_fgm': 6,
#   'team_id': 1610612765},
#  {'ab3_fg_pct': 0.342105263157895,
#   'ab3_fga': 38,
#   'ab3_fgm': 13,
#   'afg2m': 16,
#   'afg2pct': 0.5,
#   'afg3m': 13,
#   'afg3pct': 0.866666666666667,
#   'c3_fg_pct': 0.125,
#   'c3_fga': 16,
#   'c3_fgm': 2,
#   'efg': 0.450413223140496,
#   'fg2a': 67,
#   'fg2m': 32,
#   'fg2pct': 0.477611940298507,
#   'fg3a': 54,
#   'fg3m': 15,
#   'fg3pct': 0.277777777777778,
#   'fga': 121,
#   'lmr_fg_pct': 0.5,
#   'lmr_fga': 4,
#   'lmr_fgm': 2,
#   'name': 'CHA',
#   'putback_fg_pct': 0.571428571428571,
#   'putback_fga': 7,
#   'putback_fgm': 4,
#   'rim_fg_pct': 0.542857142857143,
#   'rim_fga': 35,
#   'rim_fgm': 19,
#   'smr_fg_pct': 0.392857142857143,
#   'smr_fga': 28,
#   'smr_fgm': 11,
#   'team_id': 1610612766},
#  {'ab3_fg_pct': 0.272727272727273,
#   'ab3_fga': 33,
#   'ab3_fgm': 9,
#   'afg2m': 15,
#   'afg2pct': 0.46875,
#   'afg3m': 6,
#   'afg3pct': 0.6,
#   'c3_fg_pct': 0.142857142857143,
#   'c3_fga': 7,
#   'c3_fgm': 1,
#   'efg': 0.474747474747475,
#   'fg2a': 59,
#   'fg2m': 32,
#   'fg2pct': 0.542372881355932,
#   'fg3a': 40,
#   'fg3m': 10,
#   'fg3pct': 0.25,
#   'fga': 99,
#   'lmr_fg_pct': 0.571428571428571,
#   'lmr_fga': 7,
#   'lmr_fgm': 4,
#   'name': 'GSW',
#   'putback_fg_pct': 0.8,
#   'putback_fga': 5,
#   'putback_fgm': 4,
#   'rim_fg_pct': 0.666666666666667,
#   'rim_fga': 27,
#   'rim_fgm': 18,
#   'smr_fg_pct': 0.4,
#   'smr_fga': 25,
#   'smr_fgm': 10,
#   'team_id': 1610612744},
#  {'ab3_fg_pct': 0.260869565217391,
#   'ab3_fga': 23,
#   'ab3_fgm': 6,
#   'afg2m': 9,
#   'afg2pct': 0.290322580645161,
#   'afg3m': 10,
#   'afg3pct': 0.833333333333333,
#   'c3_fg_pct': 0.545454545454545,
#   'c3_fga': 11,
#   'c3_fgm': 6,
#   'efg': 0.453703703703704,
#   'fg2a': 74,
#   'fg2m': 31,
#   'fg2pct': 0.418918918918919,
#   'fg3a': 34,
#   'fg3m': 12,
#   'fg3pct': 0.352941176470588,
#   'fga': 108,
#   'lmr_fg_pct': 0.307692307692308,
#   'lmr_fga': 13,
#   'lmr_fgm': 4,
#   'name': 'BOS',
#   'putback_fg_pct': 0.75,
#   'putback_fga': 4,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.515151515151515,
#   'rim_fga': 33,
#   'rim_fgm': 17,
#   'smr_fg_pct': 0.357142857142857,
#   'smr_fga': 28,
#   'smr_fgm': 10,
#   'team_id': 1610612738},
#  {'ab3_fg_pct': 0.25,
#   'ab3_fga': 24,
#   'ab3_fgm': 6,
#   'afg2m': 7,
#   'afg2pct': 0.233333333333333,
#   'afg3m': 4,
#   'afg3pct': 0.571428571428571,
#   'c3_fg_pct': 0.333333333333333,
#   'c3_fga': 3,
#   'c3_fgm': 1,
#   'efg': 0.460227272727273,
#   'fg2a': 61,
#   'fg2m': 30,
#   'fg2pct': 0.491803278688525,
#   'fg3a': 27,
#   'fg3m': 7,
#   'fg3pct': 0.259259259259259,
#   'fga': 88,
#   'lmr_fg_pct': 0.428571428571429,
#   'lmr_fga': 7,
#   'lmr_fgm': 3,
#   'name': 'MEM',
#   'putback_fg_pct': 0.625,
#   'putback_fga': 8,
#   'putback_fgm': 5,
#   'rim_fg_pct': 0.566666666666667,
#   'rim_fga': 30,
#   'rim_fgm': 17,
#   'smr_fg_pct': 0.416666666666667,
#   'smr_fga': 24,
#   'smr_fgm': 10,
#   'team_id': 1610612763},
#  {'ab3_fg_pct': 0.311111111111111,
#   'ab3_fga': 45,
#   'ab3_fgm': 14,
#   'afg2m': 21,
#   'afg2pct': 0.411764705882353,
#   'afg3m': 11,
#   'afg3pct': 0.647058823529412,
#   'c3_fg_pct': 0.2,
#   'c3_fga': 15,
#   'c3_fgm': 3,
#   'efg': 0.506622516556291,
#   'fg2a': 91,
#   'fg2m': 51,
#   'fg2pct': 0.56043956043956,
#   'fg3a': 60,
#   'fg3m': 17,
#   'fg3pct': 0.283333333333333,
#   'fga': 151,
#   'lmr_fg_pct': 0.318181818181818,
#   'lmr_fga': 22,
#   'lmr_fgm': 7,
#   'name': 'LAL',
#   'putback_fg_pct': 0.777777777777778,
#   'putback_fga': 9,
#   'putback_fgm': 7,
#   'rim_fg_pct': 0.714285714285714,
#   'rim_fga': 49,
#   'rim_fgm': 35,
#   'smr_fg_pct': 0.45,
#   'smr_fga': 20,
#   'smr_fgm': 9,
#   'team_id': 1610612747},
#  {'ab3_fg_pct': 0.428571428571429,
#   'ab3_fga': 35,
#   'ab3_fgm': 15,
#   'afg2m': 16,
#   'afg2pct': 0.592592592592593,
#   'afg3m': 14,
#   'afg3pct': 0.875,
#   'c3_fg_pct': 0.125,
#   'c3_fga': 8,
#   'c3_fgm': 1,
#   'efg': 0.455357142857143,
#   'fg2a': 69,
#   'fg2m': 27,
#   'fg2pct': 0.391304347826087,
#   'fg3a': 43,
#   'fg3m': 16,
#   'fg3pct': 0.372093023255814,
#   'fga': 112,
#   'lmr_fg_pct': 0.272727272727273,
#   'lmr_fga': 11,
#   'lmr_fgm': 3,
#   'name': 'NYK',
#   'putback_fg_pct': 0.5,
#   'putback_fga': 4,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.483870967741935,
#   'rim_fga': 31,
#   'rim_fgm': 15,
#   'smr_fg_pct': 0.333333333333333,
#   'smr_fga': 27,
#   'smr_fgm': 9,
#   'team_id': 1610612752},
#  {'ab3_fg_pct': 0.304347826086957,
#   'ab3_fga': 23,
#   'ab3_fgm': 7,
#   'afg2m': 15,
#   'afg2pct': 0.517241379310345,
#   'afg3m': 6,
#   'afg3pct': 0.75,
#   'c3_fg_pct': 0.0909090909090909,
#   'c3_fga': 11,
#   'c3_fgm': 1,
#   'efg': 0.431578947368421,
#   'fg2a': 61,
#   'fg2m': 29,
#   'fg2pct': 0.475409836065574,
#   'fg3a': 34,
#   'fg3m': 8,
#   'fg3pct': 0.235294117647059,
#   'fga': 95,
#   'lmr_fg_pct': 0.285714285714286,
#   'lmr_fga': 7,
#   'lmr_fgm': 2,
#   'name': 'CLE',
#   'putback_fg_pct': 0.5,
#   'putback_fga': 2,
#   'putback_fgm': 1,
#   'rim_fg_pct': 0.566666666666667,
#   'rim_fga': 30,
#   'rim_fgm': 17,
#   'smr_fg_pct': 0.416666666666667,
#   'smr_fga': 24,
#   'smr_fgm': 10,
#   'team_id': 1610612739},
#  {'ab3_fg_pct': 0.241379310344828,
#   'ab3_fga': 29,
#   'ab3_fgm': 7,
#   'afg2m': 13,
#   'afg2pct': 0.393939393939394,
#   'afg3m': 6,
#   'afg3pct': 0.666666666666667,
#   'c3_fg_pct': 0.333333333333333,
#   'c3_fga': 6,
#   'c3_fgm': 2,
#   'efg': 0.479381443298969,
#   'fg2a': 62,
#   'fg2m': 33,
#   'fg2pct': 0.532258064516129,
#   'fg3a': 35,
#   'fg3m': 9,
#   'fg3pct': 0.257142857142857,
#   'fga': 97,
#   'lmr_fg_pct': 0.533333333333333,
#   'lmr_fga': 15,
#   'lmr_fgm': 8,
#   'name': 'ATL',
#   'putback_fg_pct': 0.333333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.565217391304348,
#   'rim_fga': 23,
#   'rim_fgm': 13,
#   'smr_fg_pct': 0.5,
#   'smr_fga': 24,
#   'smr_fgm': 12,
#   'team_id': 1610612737},
#  {'ab3_fg_pct': 0.473684210526316,
#   'ab3_fga': 19,
#   'ab3_fgm': 9,
#   'afg2m': 14,
#   'afg2pct': 0.5,
#   'afg3m': 9,
#   'afg3pct': 0.818181818181818,
#   'c3_fg_pct': 0.666666666666667,
#   'c3_fga': 3,
#   'c3_fgm': 2,
#   'efg': 0.542682926829268,
#   'fg2a': 60,
#   'fg2m': 28,
#   'fg2pct': 0.466666666666667,
#   'fg3a': 22,
#   'fg3m': 11,
#   'fg3pct': 0.5,
#   'fga': 82,
#   'lmr_fg_pct': 0.2,
#   'lmr_fga': 10,
#   'lmr_fgm': 2,
#   'name': 'NOP',
#   'putback_fg_pct': 0.25,
#   'putback_fga': 8,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.52,
#   'rim_fga': 25,
#   'rim_fgm': 13,
#   'smr_fg_pct': 0.52,
#   'smr_fga': 25,
#   'smr_fgm': 13,
#   'team_id': 1610612740},
#  {'ab3_fg_pct': 0.242424242424242,
#   'ab3_fga': 33,
#   'ab3_fgm': 8,
#   'afg2m': 12,
#   'afg2pct': 0.428571428571429,
#   'afg3m': 9,
#   'afg3pct': 0.692307692307692,
#   'c3_fg_pct': 0.384615384615385,
#   'c3_fga': 13,
#   'c3_fgm': 5,
#   'efg': 0.461165048543689,
#   'fg2a': 57,
#   'fg2m': 28,
#   'fg2pct': 0.491228070175439,
#   'fg3a': 46,
#   'fg3m': 13,
#   'fg3pct': 0.282608695652174,
#   'fga': 103,
#   'lmr_fg_pct': 0.2,
#   'lmr_fga': 5,
#   'lmr_fgm': 1,
#   'name': 'UTA',
#   'putback_fg_pct': 0.333333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 2,
#   'rim_fg_pct': 0.620689655172414,
#   'rim_fga': 29,
#   'rim_fgm': 18,
#   'smr_fg_pct': 0.391304347826087,
#   'smr_fga': 23,
#   'smr_fgm': 9,
#   'team_id': 1610612762},
#  {'ab3_fg_pct': 0.0666666666666667,
#   'ab3_fga': 15,
#   'ab3_fgm': 1,
#   'afg2m': 7,
#   'afg2pct': 0.184210526315789,
#   'afg3m': 2,
#   'afg3pct': 1.0,
#   'c3_fg_pct': 0.142857142857143,
#   'c3_fga': 7,
#   'c3_fgm': 1,
#   'efg': 0.476744186046512,
#   'fg2a': 64,
#   'fg2m': 38,
#   'fg2pct': 0.59375,
#   'fg3a': 22,
#   'fg3m': 2,
#   'fg3pct': 0.0909090909090909,
#   'fga': 86,
#   'lmr_fg_pct': 0.444444444444444,
#   'lmr_fga': 27,
#   'lmr_fgm': 12,
#   'name': 'CHI',
#   'putback_fg_pct': 0.833333333333333,
#   'putback_fga': 6,
#   'putback_fgm': 5,
#   'rim_fg_pct': 0.818181818181818,
#   'rim_fga': 22,
#   'rim_fgm': 18,
#   'smr_fg_pct': 0.533333333333333,
#   'smr_fga': 15,
#   'smr_fgm': 8,
#   'team_id': 1610612741},
#  {'ab3_fg_pct': 0.323529411764706,
#   'ab3_fga': 34,
#   'ab3_fgm': 11,
#   'afg2m': 21,
#   'afg2pct': 0.477272727272727,
#   'afg3m': 8,
#   'afg3pct': 0.615384615384615,
#   'c3_fg_pct': 0.222222222222222,
#   'c3_fga': 9,
#   'c3_fgm': 2,
#   'efg': 0.508,
#   'fg2a': 82,
#   'fg2m': 44,
#   'fg2pct': 0.536585365853659,
#   'fg3a': 43,
#   'fg3m': 13,
#   'fg3pct': 0.302325581395349,
#   'fga': 125,
#   'lmr_fg_pct': 0.473684210526316,
#   'lmr_fga': 19,
#   'lmr_fgm': 9,
#   'name': 'PHI',
#   'putback_fg_pct': 0.428571428571429,
#   'putback_fga': 7,
#   'putback_fgm': 3,
#   'rim_fg_pct': 0.617647058823529,
#   'rim_fga': 34,
#   'rim_fgm': 21,
#   'smr_fg_pct': 0.482758620689655,
#   'smr_fga': 29,
#   'smr_fgm': 14,
#   'team_id': 1610612755}]
